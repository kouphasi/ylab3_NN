# %%
import numpy as np
import scipy.special
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
from execute_function import nn

# %%
y1, z1 = nn(16)

# %%
y2, z2 = nn(32)

# %%
y3, z3 = nn(64)

# %%
y4, z4 = nn(128)

# %%
fig,ax = plt.subplots(2,2)
ax[0,0].set_title("hidden_node=16")
ax[0,1].set_title("hidden_node=32")
ax[1,0].set_title("hidden_node=64")
ax[1,1].set_title("hidden_node=128")
ax[0,0].plot(y1)
ax[0,1].plot(y2)
ax[1,0].plot(y3)
ax[1,1].plot(y4)
ax[0,0].set_ylim(0.00001,0.006)
ax[0,1].set_ylim(0.00001,0.006)
ax[1,0].set_ylim(0.00001,0.006)
ax[1,1].set_ylim(0.00001,0.006)
plt.subplots_adjust(left=0.5,
                    bottom=0.1, 
                    right=1.5, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)
plt.show()

# %%
fig,ax = plt.subplots(2,2)
ax[0,0].set_title("hidden_node=16")
ax[0,1].set_title("hidden_node=32")
ax[1,0].set_title("hidden_node=64")
ax[1,1].set_title("hidden_node=128")
ax[0,0].plot(z1)
ax[0,1].plot(z2)
ax[1,0].plot(z3)
ax[1,1].plot(z4)
ax[0,0].set_ylim(0.001,3)
ax[0,1].set_ylim(0.001,3)
ax[1,0].set_ylim(0.001,3)
ax[1,1].set_ylim(0.001,3)
plt.subplots_adjust(left=0.5,
                    bottom=0.1, 
                    right=1.5, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)
plt.show()

# %%
jplt.plot(y1)
plt.title("Learning rate = 0.4")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 jplt.plot(y1)
#       2 plt.title("Learning rate = 0.4")
#
# NameError: name 'jplt' is not defined

# %%
plt.plot(z1)

# %%
plt.plot(y1)
plt.title("MSE(hidden=2)")
# Out:
# Text(0.5, 1.0, 'MSE(hidden=2)')

# %%
y2 = nn(16)
y2
# Out:
# [0.18413400454357423,
#  0.1839479712873588,
#  0.18392189872851372,
#  0.18342202733869012,
#  0.18517495139623244,
#  0.18517078691550407,
#  0.18533922751673393,
#  0.18511315989166957,
#  0.18079494244739167,
#  0.17929820068209537,
#  0.1792093215144242,
#  0.17930364450410968,
#  0.17959458229689962,
#  0.17968265654609494,
#  0.1801246368860528,
#  0.180017721843419,
#  0.1798531702799947,
#  0.17982305875551088,
#  0.17930474469508206,
#  0.17937931528557394,
#  0.17946513556013477,
#  0.17920313690822087,
#  0.17988486566012757,
#  0.1799128700633958,
#  0.17972204944876757,
#  0.18105900920252443,
#  0.1807635265176312,
#  0.18148217416226423,
#  0.18176312205066322,
#  0.18042750325723422,
#  0.1803057888256194,
#  0.1810445310002494,
#  0.18297422913474348,
#  0.1839161767788271,
#  0.1839678160699392,
#  0.18352959595898716,
#  0.18213868848049372,
#  0.18069677110312346,
#  0.18030151910282002,
#  0.17886126073634806,
#  0.1798384975484195,
#  0.179214914112125,
# ...

# %%
y3 = nn(64)
y3
# Out:
# [0.19245300019995096,
#  0.1912846799272312,
#  0.19117884228543738,
#  0.20467512912177505,
#  0.21333030819524293,
#  0.21434794108286212,
#  0.21313992271901172,
#  0.21224695378439146,
#  0.21320478937802306,
#  0.2114864401571916,
#  0.21165344252915755,
#  0.21178171044226862,
#  0.20496121717610305,
#  0.20393038051708107,
#  0.20454004355865765,
#  0.20333636228293742,
#  0.20901723128801175,
#  0.2086227618478769,
#  0.1868152957280859,
#  0.18678020186956473,
#  0.18678619882323585,
#  0.18536413494484744,
#  0.18795707430354094,
#  0.18746527725703147,
#  0.18675081584675127,
#  0.1799884438616226,
#  0.18368189884319935,
#  0.18438438930757137,
#  0.18022695967047123,
#  0.17754514644813055,
#  0.1941158453803004,
#  0.18279003398534335,
#  0.1855161764853468,
#  0.1869749559994401,
#  0.18730155101647467,
#  0.19084507929887962,
#  0.1734692925300077,
#  0.1741434636187095,
#  0.17525293669624226,
#  0.171287138346165,
#  0.17379078212075352,
#  0.17064343017025754,
# ...

# %%
y4 = nn(128)
y4
# Out:
# [0.20659587475318705,
#  0.20420609256035216,
#  0.20417849688797116,
#  0.21660821363658697,
#  0.23312583173569582,
#  0.2344536371651,
#  0.23409858781448067,
#  0.23281942785133797,
#  0.22198296903544495,
#  0.21737609666456284,
#  0.21821555076785498,
#  0.2199872910028342,
#  0.21665511171202084,
#  0.2129499039417126,
#  0.2146333896522233,
#  0.21310941593410934,
#  0.21078184375195427,
#  0.21058730674275705,
#  0.18374226891280943,
#  0.18355441364181546,
#  0.18483091050834574,
#  0.18372843844825135,
#  0.18650117958147436,
#  0.18713422435129767,
#  0.18626880173851187,
#  0.18274417977901633,
#  0.1877833328342326,
#  0.19279383497454022,
#  0.17653340324301828,
#  0.1787637520880621,
#  0.24213940656899668,
#  0.18770976328972608,
#  0.19540583363901115,
#  0.19934907068775004,
#  0.20021289435732698,
#  0.20058681100673162,
#  0.19093597794061917,
#  0.19257614266521775,
#  0.18079556926822338,
#  0.18292066761047313,
#  0.1893976473098246,
#  0.18461397751222142,
# ...

# %%
plt.plot(y4,".")
plt.title(f"MSE(hidden={128})")
plt.xlabel("Learn times")
# Out:
# Text(0.5, 0, 'Learn times')

# %%
y5 = nn(256)
y5
# Out:
# [0.22399430639457066,
#  0.22046539250938618,
#  0.22039546004604535,
#  0.25257501363913637,
#  0.25492865450875096,
#  0.2583958858729703,
#  0.2558685058669391,
#  0.2531942032873533,
#  0.29138596217031654,
#  0.26026185329356305,
#  0.2622011655155624,
#  0.2628656226366478,
#  0.2610159544676528,
#  0.25040494674149216,
#  0.25124189239251804,
#  0.24791222182517073,
#  0.248133467744173,
#  0.24785027927716988,
#  0.17512099519068638,
#  0.17555508427960229,
#  0.17677273665200732,
#  0.17516874509006503,
#  0.18079660288029564,
#  0.18155698105295204,
#  0.17976938277047386,
#  0.17844363556878165,
#  0.1966627550873597,
#  0.20196907959535107,
#  0.175200026281021,
#  0.1885054002919149,
#  0.21359575705741646,
#  0.21010544013137103,
#  0.20399215018069844,
#  0.2115988840714938,
#  0.21430828339196673,
#  0.21700638922418744,
#  0.2055031291282809,
#  0.20317248602349672,
#  0.17671237401574288,
#  0.17773145840500743,
#  0.18523672239409728,
#  0.17483417343664254,
# ...

# %%
y6 = nn(512)
y6
# Out:
# [0.32185336283998406,
#  0.31677926499238596,
#  0.31676128457578157,
#  0.35105088356032915,
#  0.3040255153996118,
#  0.3127570944754214,
#  0.3037368784320344,
#  0.30180300047037817,
#  0.25532053785223136,
#  0.2518113165477191,
#  0.25479136700706106,
#  0.25482840090682846,
#  0.24858301731289098,
#  0.22483699627962578,
#  0.22461231303298004,
#  0.22073500275782704,
#  0.23613053022126598,
#  0.23594949763747974,
#  0.24753857610724694,
#  0.2442252085659853,
#  0.23771792504913053,
#  0.23789318415925853,
#  0.20509716716018705,
#  0.2053554609497342,
#  0.2047550930448723,
#  0.1924366813500706,
#  0.29514260772263123,
#  0.3199404760942049,
#  0.20462066858333186,
#  0.19159944198470708,
#  0.2986694352856617,
#  0.2238429664342071,
#  0.19525635454399437,
#  0.2003630049053292,
#  0.20290694151832775,
#  0.20214797310653634,
#  0.19295252802498725,
#  0.19243128337459867,
#  0.18077224309558784,
#  0.17798745223242682,
#  0.18022707259790097,
#  0.1738033659409373,
# ...

# %%
plt.plot(y6)
plt.title("MSE (hidden=512)")
# Out:
# Text(0.5, 1.0, 'MSE (hidden=512)')

# %%
y7 = nn(1024)
y7
# Out:
# [0.288713745636232,
#  0.28304289996089627,
#  0.2829881596135521,
#  0.3330152365945195,
#  0.29868625843658336,
#  0.30838061159163516,
#  0.2966156971725637,
#  0.2946176013806681,
#  0.4180043892279767,
#  0.3523197563414388,
#  0.3572671460714586,
#  0.3564683694133705,
#  0.3538994140485085,
#  0.2777019936148913,
#  0.27771014547338785,
#  0.2720797946103285,
#  0.2777217693541734,
#  0.27724037183269823,
#  0.3312142993290767,
#  0.32239263278169983,
#  0.2962076461216853,
#  0.2968825498176727,
#  0.20212997377241246,
#  0.20156703680538743,
#  0.202138174967957,
#  0.18584184525407166,
#  0.33482581904384284,
#  0.3614053593403639,
#  0.2639679056750539,
#  0.21630051299282754,
#  0.4592061970932559,
#  0.4302627899988478,
#  0.22031909555077528,
#  0.22300274127182582,
#  0.22417787461274827,
#  0.21409792095530047,
#  0.1906772897881187,
#  0.19933267467277194,
#  0.18597708868772717,
#  0.19033747030792145,
#  0.18757425635574446,
#  0.17702183033564972,
# ...

# %%
plt.plot(y7)
plt.title(f"MSE(hidden={1024})")
plt.xlabel("Learn times")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 plt.plot(y7)
#       2 plt.title(f"MSE(hidden={1024})")
#       3 plt.xlabel("Learn times")
#
# NameError: name 'y7' is not defined

# %%
y3[-1]
# Out:
# 0.0007372541984346116

# %%
z3[-1]
# Out:
# 0.6194961396964522
