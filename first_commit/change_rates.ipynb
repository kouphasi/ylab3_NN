# %%
import numpy as np
import scipy.special
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
from execute_function import nn

# %%
y1, z1 = nn(0.05)

# %%
y2, z2 = nn(0.1)

# %%
y3, z3 = nn(0.3)

# %%
y4, z4 = nn(0.4)

# %%
fig,ax = plt.subplots(2,2)
ax[0,0].set_title("learning_rates=0.05")
ax[0,1].set_title("learning_rates=0.1")
ax[1,0].set_title("learning_rates=0.3")
ax[1,1].set_title("learning_rates=0.4")
ax[0,0].plot(y1)
ax[0,1].plot(y2)
ax[1,0].plot(y3)
ax[1,1].plot(y4)
ax[0,0].set_ylim(0,0.005)
ax[0,1].set_ylim(0,0.005)
ax[1,0].set_ylim(0,0.005)
ax[1,1].set_ylim(0,0.005)
plt.subplots_adjust(left=0.5,
                    bottom=0.1, 
                    right=1.5, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)
plt.show()

# %%
fig,ax = plt.subplots(2,2)
ax[0,0].set_title("learning_rates=0.05")
ax[0,1].set_title("learning_rates=0.1")
ax[1,0].set_title("learning_rates=0.3")
ax[1,1].set_title("learning_rates=0.4")
ax[0,0].plot(z1)
ax[0,1].plot(z2)
ax[1,0].plot(z3)
ax[1,1].plot(z4)
ax[0,0].set_ylim(0,3)
ax[0,1].set_ylim(0,3)
ax[1,0].set_ylim(0,3)
ax[1,1].set_ylim(0,3)
plt.subplots_adjust(left=0.5,
                    bottom=0.1, 
                    right=1.5, 
                    top=0.9, 
                    wspace=0.2, 
                    hspace=0.35)
plt.show()
